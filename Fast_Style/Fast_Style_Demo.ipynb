# %%
# %matplotlib notebook
from utils import *
from lossnet import *
from transformer import *
import os
import numpy as np
import torch
from torch import nn
from matplotlib import pyplot as plt

# %% [markdown]
# # Instructions
#
# For each style target below, set `img` to choose the content image you would like to try.
# You can pick any of the named images below or choose an image from the COCO testing set, by passing dataset[i]

# %%
dataset_root_dir = '/datasets/COCO-2015'
dataset = Custom_Data_Loader(dataset_root_dir, mode='test2015')

# %%
img_size = (256,256)
mountain = prep_style('Test_Images/mountain.jpg', img_size)
cablecar = prep_style('Test_Images/cablecar.jpg', img_size)
village = prep_style('Test_Images/village.jpg', img_size)
chicago = prep_style('Test_Images/chicago.jpg',img_size)

# %% [markdown]
# ## The Great Wave off Kanagawa

# %%
kanagawa_net = TransNet()
optimizerk = torch.optim.Adam(kanagawa_net.parameters(), lr=1e-3)
style = prep_style('Style_Images/kanagawa.jpg', img_size)


ep, c, s, t = load_model(kanagawa_net, optimizerk, 'Models/good_kanagawa_model.pth.tar')

img = mountain
with torch.no_grad():
    img_trans = kanagawa_net(img)
img_trans = (torch.ones((1,3,1,1), dtype=torch.float32).to(device).add(img_trans)).div_(2)


fig, ax = plt.subplots(1,3, figsize=(8,2))
[axi.set_axis_off() for axi in ax.ravel()]

imshow(img, ax[1])
imshow(style, ax[0])
imshow(img_trans, ax[2])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## Fireworks Image

# %%
fire_net = TransNet()
optimizerf = torch.optim.Adam(fire_net.parameters(), lr=1e-3)
style = prep_style('Style_Images/fireworks.jpg', img_size)


ep, c, s, t = load_model(fire_net, optimizerf, 'Models/fireworks_model.pth.tar')

img = mountain
with torch.no_grad():
    img_trans = fire_net(img)
img_trans = (torch.ones((1,3,1,1), dtype=torch.float32).to(device).add(img_trans)).div_(2)


fig, ax = plt.subplots(1,3, figsize=(8,2))
[axi.set_axis_off() for axi in ax.ravel()]

imshow(img, ax[1])
imshow(style, ax[0])
imshow(img_trans, ax[2])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Nympheas

# %%
lilies_net = TransNet()
optimizerf = torch.optim.Adam(lilies_net.parameters(), lr=1e-3)
style = prep_style('Style_Images/monet_lilies.jpg', img_size)


ep, c, s, t = load_model(lilies_net, optimizerf, 'Models/lilies.pth.tar')

img = mountain
with torch.no_grad():
    img_trans = fire_net(img)
img_trans = (torch.ones((1,3,1,1), dtype=torch.float32).to(device).add(img_trans)).div_(2)


fig, ax = plt.subplots(1,3, figsize=(8,2))
[axi.set_axis_off() for axi in ax.ravel()]

imshow(img, ax[1])
imshow(style, ax[0])
imshow(img_trans, ax[2])
